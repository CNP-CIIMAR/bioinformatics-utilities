# %%
# script to find substructure of fatty acids

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
pip install pikachu-chem
# Out:
# ...
#      -------------------------------------- 101.3/101.3 kB 5.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#!/usr/bin/env python
import pikachu
#from pikachu.general import highlight_substructure
from pikachu.general import draw_smiles
from pikachu.general import highlight_substructure


acido_acetico = "CCCCCCC(=O)O"
tetronomycin = "C[C@H]1CCC[C@H]([C@@H]1[C@@H](C)C(=O)C2=C(C(=C)OC2=O)O)/C=C(\CO)/[C@@H]3[C@H](CC[C@@H](O3)/C=C/C[C@@H]4CC[C@H](O4)[C@@H](C)OC)C"
# Highlighting a single occurrence of a single substructure
highlight_substructure(acido_acetico, tetronomycin, search_mode='single')
#BGC0000140= draw_smiles("CCCCCCCCCCCCCCCC(=O)C1=C(C(OC1=O)CO)O")

# %%
acido_acetico = "CCCCC(=O)O"
salinomycin = "CC[C@H](C(=O)O)[C@H]1CC[C@H](C)[C@H]([C@@H](C)[C@H](O)[C@H](C)C(=O)[C@H](CC)C2OC3(C=C[C@@H](O)[C@]4(CC[C@@](C)([C@H]5CC[C@](O)(CC)[C@H](C)O5)O4)O3)[C@H](C)C[C@@H]2C)O1"
# Highlighting a single occurrence of a single substructure
highlight_substructure(acido_acetico, salinomycin, search_mode='single')

# %%
acido_pamitico = "CCCCCCCCCCCCCCCCC(=O)O"
hexadecanoyl_furan ="CCCCCCCCCCCCCCCC(=O)C1=C(C(OC1=O)CO)O"
highlight_substructure(acido_pamitico, hexadecanoyl_furan, search_mode='single')

# %%
help(
